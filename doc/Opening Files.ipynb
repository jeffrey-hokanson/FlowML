# %% [markdown]
# ## Listing Files
# To see what files are avalible in the current working directory, we can simply access external POSIX shell commands using `!`

# %%
# !ls
# Out:
# Opening Files.ipynb  Setting up the server.ipynb  visne_all_a.fcs

# %% [markdown]
# ## Loading Data
# FlowML includes the ability to import FCS files commonly produced by flow cytometry instruments.  The `read` function in `fcs` provides a low level interface to FCS files.

# %%
from flowml import fcs

# %%
(data, metadata, analysis, meta_analysis) = fcs.read('visne_all_a.fcs')

# %%
print data.shape
# Out:
# (40, 128617)

# %% [markdown]
# ## Using Pandas
# A natural choice of a better container for this data would be Pandas DataFrame

# %%
import pandas as pd

fd = pd.DataFrame(np.transpose(data), columns = map(lambda j: metadata['$P{}N'.format(j)], range(1,data.shape[0]+1)))

# %%
fd['CD179a(Sm149)Dd']
# Out:
# 0     47.279396
# 1     68.825966
# 2     -0.147978
# 3     22.016228
# 4     23.820803
# 5     11.423415
# 6      2.231983
# 7     29.953779
# 8      6.614843
# 9     35.686043
# 10    11.094675
# 11     3.024146
# 12    11.778513
# 13    11.620893
# 14    -0.029143
# ...
# 128602    -2.445024
# 128603     0.291715
# 128604     7.451439
# 128605     4.464802
# 128606     6.662507
# 128607     3.636566
# 128608    12.670486
# 128609    13.672915
# 128610    -2.180968
# 128611    26.431576
# 128612     4.964794
# 128613     2.320077
# 128614    12.423702
# 128615     0.327916
# 128616     6.477512
# Name: CD179a(Sm149)Dd, Length: 128617, dtype: float32

# %%
from flowml.flowdata import FlowData
fd = FlowData('visne_all_a.fcs')

# %%
fd['CD179a(Sm149)Dd']
# Out:
# 0     47.279396
# 1     68.825966
# 2     -0.147978
# 3     22.016228
# 4     23.820803
# 5     11.423415
# 6      2.231983
# 7     29.953779
# 8      6.614843
# 9     35.686043
# 10    11.094675
# 11     3.024146
# 12    11.778513
# 13    11.620893
# 14    -0.029143
# ...
# 128602    -2.445024
# 128603     0.291715
# 128604     7.451439
# 128605     4.464802
# 128606     6.662507
# 128607     3.636566
# 128608    12.670486
# 128609    13.672915
# 128610    -2.180968
# 128611    26.431576
# 128612     4.964794
# 128613     2.320077
# 128614    12.423702
# 128615     0.327916
# 128616     6.477512
# Name: CD179a(Sm149)Dd, Length: 128617, dtype: float64

# %%
fig = fd.hist(column = 'CD179a(Sm149)Dd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ef877a06b435> in <module>()
#       1 fig = fd.hist(column = 'CD179a(Sm149)Dd')
# ----> 2 mpld3.display()
#
# NameError: name 'mpld3' is not defined

# %% [markdown]
# ## Fancy Plotting

# %%
import matplotlib.pyplot as plt
import mpld3
fd.hist(column = 'CD179a(Sm149)Dd', bins = 100)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el2397047544586405212272704"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
print metadata['$P5N']
# Out:
# CD19(Nd142)Dd
